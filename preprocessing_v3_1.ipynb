# %%
import pandas as pd

# %%
df2015 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2015.xlsx", header=16)
df2016 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2016.xlsx", header=16)
df2017 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2017.xlsx", header=16)
df2018 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2018.xlsx", header=16)
df2019 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2019.xlsx", header=16)
df2020 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2020.xlsx", header=16)
df2021 = pd.read_excel("/Users/2020/Housing-Market_Price_Project/아파트_실거래가/apt_transaction_2021.xlsx", header=16)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df2015
# Out:
#                   시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  \
# 0       서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201501
# 1       서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201503
# 2       서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201503
# 3       서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201508
# 4       서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  201501
# ...               ...    ...    ...  ...             ...      ...     ...
# 120218  서울특별시 중랑구 중화동   11-7   11.0  7.0     현대휴앤미(102동)    77.71  201505
# 120219  서울특별시 중랑구 중화동   11-7   11.0  7.0     현대휴앤미(102동)    76.43  201505
# 120220  서울특별시 중랑구 중화동   11-7   11.0  7.0     현대휴앤미(102동)    67.36  201506
# 120221  서울특별시 중랑구 중화동   11-7   11.0  7.0     현대휴앤미(102동)    64.48  201507
# 120222  서울특별시 중랑구 중화동   11-7   11.0  7.0     현대휴앤미(102동)    76.43  201510
#
#         계약일        거래금액(만원)  층  건축년도          도로명  해제사유발생일
# ...

# %%
df2015.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일'],
#       dtype='object')

# %%
list_df = [df2015, df2016, df2017, df2018, df2019, df2020, df2021]

# %%
df = pd.DataFrame(columns=['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
       '층', '건축년도', '도로명', '해제사유발생일'])
df.columns==df2015.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
for dfYYYY in list_df:
    df = df.append(dfYYYY)

# %%
df
# Out:
#                  시군구      번지     본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201501
# 1      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201503
# 2      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201503
# 3      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201508
# 4      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  201501
# ...              ...     ...    ...   ...             ...      ...     ...
# 37732  서울특별시 중랑구 중화동     450  450.0   0.0             한신2    84.03  202108
# 37733  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    57.66  202102
# 37734  서울특별시 중랑구 중화동  274-75  274.0  75.0         한영(102)    72.22  202105
# 37735  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)    58.46  202107
# 37736  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)   104.93  202108
#
#       계약일        거래금액(만원)  층  건축년도         도로명  해제사유발생일
# ...

# %%
df['dong'] = df['시군구'].str.split().str[2]
df
# Out:
#                  시군구      번지     본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201501
# 1      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201503
# 2      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201503
# 3      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201508
# 4      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  201501
# ...              ...     ...    ...   ...             ...      ...     ...
# 37732  서울특별시 중랑구 중화동     450  450.0   0.0             한신2    84.03  202108
# 37733  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    57.66  202102
# 37734  서울특별시 중랑구 중화동  274-75  274.0  75.0         한영(102)    72.22  202105
# 37735  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)    58.46  202107
# 37736  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)   104.93  202108
#
#       계약일        거래금액(만원)  층  건축년도         도로명  해제사유발생일 dong
# ...

# %%
df['거래금액(만원)'] = df['거래금액(만원)'].str.replace(',', '')

# %%
df
# Out:
#                  시군구      번지     본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201501
# 1      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201503
# 2      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201503
# 3      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  201508
# 4      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  201501
# ...              ...     ...    ...   ...             ...      ...     ...
# 37732  서울특별시 중랑구 중화동     450  450.0   0.0             한신2    84.03  202108
# 37733  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    57.66  202102
# 37734  서울특별시 중랑구 중화동  274-75  274.0  75.0         한영(102)    72.22  202105
# 37735  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)    58.46  202107
# 37736  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)   104.93  202108
#
#       계약일       거래금액(만원)  층  건축년도         도로명  해제사유발생일 dong
# ...

# %%
df.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', 'dong'],
#       dtype='object')

# %%
df_temp = df[['dong', '도로명', '단지명', '전용면적(㎡)', '건축년도', '계약년월', '계약일', '층', '거래금액(만원)']]

# %%
df_temp
# Out:
#       dong         도로명             단지명  전용면적(㎡)  건축년도    계약년월 계약일  층  \
# 0      개포동     언주로 103  개포2차현대아파트(220)    77.75  1988  201501  11  5
# 1      개포동     언주로 103  개포2차현대아파트(220)    77.75  1988  201503   3  5
# 2      개포동     언주로 103  개포2차현대아파트(220)    77.75  1988  201503   7  2
# 3      개포동     언주로 103  개포2차현대아파트(220)    77.75  1988  201508  16  6
# 4      개포동       언주로 3  개포6차우성아파트1동~8동    79.97  1987  201501  29  5
# ...    ...         ...             ...      ...   ...     ...  .. ..
# 37732  중화동     동일로 752             한신2    84.03  1998  202108  21  3
# 37733  중화동  동일로144길 74         한영(101)    57.66  2003  202102  27  5
# 37734  중화동  동일로144길 74         한영(102)    72.22  2003  202105   4  4
# 37735  중화동  동일로144길 74         한영(103)    58.46  2003  202107   1  2
# 37736  중화동  동일로144길 74         한영(103)   104.93  2003  202108  20  7
#
#             거래금액(만원)
# 0              60000
# 1              65000
# 2              62500
# 3              68000
# 4              73000
# ...

# %%
columns_df={'도로명':'addr_road',
            '단지명':'apt',
            '전용면적(㎡)':'exclusive_use_area',
            '건축년도':'year_of_completion',
            '계약년월':'transaction_year_month',
            '계약일':'transaction_date',
            '층':'floor',
            '거래금액(만원)':'transaction_real_price'
            }
df_temp = df_temp.rename(columns=columns_df_temp)
df_temp
# Out:
#       dong   addr_road             apt  exclusive_use_area year_of_completion  \
# 0      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 1      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 2      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 3      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 4      개포동       언주로 3  개포6차우성아파트1동~8동               79.97               1987
# ...    ...         ...             ...                 ...                ...
# 37732  중화동     동일로 752             한신2               84.03               1998
# 37733  중화동  동일로144길 74         한영(101)               57.66               2003
# 37734  중화동  동일로144길 74         한영(102)               72.22               2003
# 37735  중화동  동일로144길 74         한영(103)               58.46               2003
# 37736  중화동  동일로144길 74         한영(103)              104.93               2003
#
# ...

# %%
df_temp
# Out:
#       dong   addr_road             apt  exclusive_use_area year_of_completion  \
# 0      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 1      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 2      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 3      개포동     언주로 103  개포2차현대아파트(220)               77.75               1988
# 4      개포동       언주로 3  개포6차우성아파트1동~8동               79.97               1987
# ...    ...         ...             ...                 ...                ...
# 37732  중화동     동일로 752             한신2               84.03               1998
# 37733  중화동  동일로144길 74         한영(101)               57.66               2003
# 37734  중화동  동일로144길 74         한영(102)               72.22               2003
# 37735  중화동  동일로144길 74         한영(103)               58.46               2003
# 37736  중화동  동일로144길 74         한영(103)              104.93               2003
#
# ...

# %%
df_temp.to_csv("./preprocessing_apt_price.csv")
